# %%
from NVAR import NVAR
from sklearn.linear_model import Ridge

import numpy as np
from pprint import pprint

import matplotlib.pyplot as plt

# %%
delay = 2
strides = [1, 3]
order = 2
update_rate = 1.

nvar = NVAR(delay, strides, order, update_rate)

t = np.linspace(0, 100, 1000)
X_1 = np.sin(t)
X_2 = np.cos(t)
X = np.stack([X_1, X_2], axis=0)

nvar.fit(X)
print(nvar.n_features)
pprint(nvar.feature_names())
# Out:
# 44
# ['x0(t)',
#  'x1(t)',
#  'x0(t)',
#  'x1(t)',
#  'x0(t-1)',
#  'x1(t-1)',
#  'x0(t-3)',
#  'x1(t-3)',
#  'x0(t)^2',
#  'x0(t)*x1(t)',
#  'x0(t)^2',
#  'x0(t)*x1(t)',
#  'x0(t)*x0(t-1)',
#  'x0(t)*x1(t-1)',
#  'x0(t)*x0(t-3)',
#  'x0(t)*x1(t-3)',
#  'x1(t)^2',
#  'x1(t)*x0(t)',
#  'x1(t)^2',
#  'x1(t)*x0(t-1)',
#  'x1(t)*x1(t-1)',
#  'x1(t)*x0(t-3)',
#  'x1(t)*x1(t-3)',
#  'x0(t)^2',
#  'x0(t)*x1(t)',
#  'x0(t)*x0(t-1)',
#  'x0(t)*x1(t-1)',
#  'x0(t)*x0(t-3)',
#  'x0(t)*x1(t-3)',
#  'x1(t)^2',
#  'x1(t)*x0(t-1)',
#  'x1(t)*x1(t-1)',
#  'x1(t)*x0(t-3)',
#  'x1(t)*x1(t-3)',
#  'x0(t-1)^2',
#  'x0(t-1)*x1(t-1)',
#  'x0(t-1)*x0(t-3)',
#  'x0(t-1)*x1(t-3)',
#  'x1(t-1)^2',
#  'x1(t-1)*x0(t-3)',
#  'x1(t-1)*x1(t-3)',
#  'x0(t-3)^2',
#  'x0(t-3)*x1(t-3)',
#  'x1(t-3)^2']

# %%
states = nvar.transform(X)
n_valid_timestep, n_features = states.shape
n_valid_timestep
# Out:
# 997

# %%
model = Ridge(alpha=1.0)

tau = 200

min_t = nvar.valid_index


y_train = X[:, min_t+tau:].T
X_train = states[:-tau,:]

#plt.plot(X_train)
plt.plot(y_train)

model.fit(X_train, y_train)
# Out:
# Ridge()

# %%
from sklearn.metrics import r2_score

y_pred = model.predict(X_train)

r2 = r2_score(y_train, y_pred)
r2
# Out:
# 0.999999606322342
